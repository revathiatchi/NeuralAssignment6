# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Loading the diabetes dataset
dataset = pd.read_csv('diabetes.csv')

# Splitting the dataset into the dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# Normalizing the data using StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy'])

# Training the model
history = model.fit(X_train, y_train, epochs=100,
                    batch_size=10, validation_split=0.2)

# Evaluating the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# C:\Users\REVATHI\AppData\Local\Temp\ipykernel_3964\738326326.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\REVATHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\REVATHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\REVATHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\REVATHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\REVATHI\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 49/49 [==============================] - 2s 17ms/step - loss: 0.8719 - accuracy: 0.3306 - val_loss: 0.7331 - val_accuracy: 0.4309
# Epoch 2/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.7666 - accuracy: 0.3388 - val_loss: 0.6922 - val_accuracy: 0.5528
# Epoch 3/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.7100 - accuracy: 0.4857 - val_loss: 0.6726 - val_accuracy: 0.6504
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.6747 - accuracy: 0.6367 - val_loss: 0.6601 - val_accuracy: 0.6667
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.6485 - accuracy: 0.6857 - val_loss: 0.6491 - val_accuracy: 0.6667
# Epoch 6/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.6254 - accuracy: 0.7224 - val_loss: 0.6383 - val_accuracy: 0.6748
# Epoch 7/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.6040 - accuracy: 0.7224 - val_loss: 0.6274 - val_accuracy: 0.6748
# Epoch 8/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5832 - accuracy: 0.7327 - val_loss: 0.6156 - val_accuracy: 0.6829
# Epoch 9/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5637 - accuracy: 0.7327 - val_loss: 0.6046 - val_accuracy: 0.7154
# Epoch 10/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.7286 - val_loss: 0.5941 - val_accuracy: 0.7154
# Epoch 11/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5317 - accuracy: 0.7347 - val_loss: 0.5852 - val_accuracy: 0.7154
# Epoch 12/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5193 - accuracy: 0.7347 - val_loss: 0.5773 - val_accuracy: 0.6992
# Epoch 13/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.5089 - accuracy: 0.7367 - val_loss: 0.5708 - val_accuracy: 0.7073
# Epoch 14/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.5003 - accuracy: 0.7367 - val_loss: 0.5665 - val_accuracy: 0.7073
# Epoch 15/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4936 - accuracy: 0.7449 - val_loss: 0.5613 - val_accuracy: 0.7073
# Epoch 16/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4874 - accuracy: 0.7469 - val_loss: 0.5565 - val_accuracy: 0.7154
# Epoch 17/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4815 - accuracy: 0.7408 - val_loss: 0.5503 - val_accuracy: 0.7236
# Epoch 18/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4765 - accuracy: 0.7571 - val_loss: 0.5460 - val_accuracy: 0.7317
# Epoch 19/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.7633 - val_loss: 0.5438 - val_accuracy: 0.7398
# Epoch 20/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4680 - accuracy: 0.7755 - val_loss: 0.5425 - val_accuracy: 0.7317
# Epoch 21/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4645 - accuracy: 0.7735 - val_loss: 0.5403 - val_accuracy: 0.7236
# Epoch 22/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4615 - accuracy: 0.7796 - val_loss: 0.5400 - val_accuracy: 0.7236
# Epoch 23/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4576 - accuracy: 0.7735 - val_loss: 0.5392 - val_accuracy: 0.7236
# Epoch 24/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4539 - accuracy: 0.7816 - val_loss: 0.5398 - val_accuracy: 0.7236
# Epoch 25/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4518 - accuracy: 0.7776 - val_loss: 0.5408 - val_accuracy: 0.7317
# Epoch 26/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4486 - accuracy: 0.7837 - val_loss: 0.5397 - val_accuracy: 0.7236
# Epoch 27/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4466 - accuracy: 0.7857 - val_loss: 0.5397 - val_accuracy: 0.7236
# Epoch 28/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.7857 - val_loss: 0.5402 - val_accuracy: 0.7154
# Epoch 29/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.7857 - val_loss: 0.5413 - val_accuracy: 0.7154
# Epoch 30/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4408 - accuracy: 0.7857 - val_loss: 0.5435 - val_accuracy: 0.7073
# Epoch 31/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4393 - accuracy: 0.7939 - val_loss: 0.5471 - val_accuracy: 0.7154
# Epoch 32/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4372 - accuracy: 0.7878 - val_loss: 0.5471 - val_accuracy: 0.7073
# Epoch 33/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.7878 - val_loss: 0.5499 - val_accuracy: 0.7154
# Epoch 34/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.7898 - val_loss: 0.5484 - val_accuracy: 0.7154
# Epoch 35/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4329 - accuracy: 0.7898 - val_loss: 0.5509 - val_accuracy: 0.7154
# Epoch 36/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.7878 - val_loss: 0.5534 - val_accuracy: 0.7317
# Epoch 37/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4297 - accuracy: 0.7939 - val_loss: 0.5532 - val_accuracy: 0.7154
# Epoch 38/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4289 - accuracy: 0.7878 - val_loss: 0.5567 - val_accuracy: 0.7154
# Epoch 39/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4273 - accuracy: 0.7939 - val_loss: 0.5565 - val_accuracy: 0.7154
# Epoch 40/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4267 - accuracy: 0.7939 - val_loss: 0.5601 - val_accuracy: 0.7154
# Epoch 41/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4255 - accuracy: 0.8000 - val_loss: 0.5600 - val_accuracy: 0.7154
# Epoch 42/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4246 - accuracy: 0.7939 - val_loss: 0.5630 - val_accuracy: 0.7154
# Epoch 43/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.8000 - val_loss: 0.5643 - val_accuracy: 0.7236
# Epoch 44/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4222 - accuracy: 0.8020 - val_loss: 0.5669 - val_accuracy: 0.7073
# Epoch 45/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4222 - accuracy: 0.8020 - val_loss: 0.5669 - val_accuracy: 0.7154
# Epoch 46/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8041 - val_loss: 0.5693 - val_accuracy: 0.7073
# Epoch 47/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8082 - val_loss: 0.5704 - val_accuracy: 0.6992
# Epoch 48/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8122 - val_loss: 0.5704 - val_accuracy: 0.6992
# Epoch 49/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4188 - accuracy: 0.8082 - val_loss: 0.5724 - val_accuracy: 0.7073
# Epoch 50/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4177 - accuracy: 0.8122 - val_loss: 0.5733 - val_accuracy: 0.6992
# Epoch 51/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4171 - accuracy: 0.8020 - val_loss: 0.5752 - val_accuracy: 0.6992
# Epoch 52/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4171 - accuracy: 0.8122 - val_loss: 0.5794 - val_accuracy: 0.7073
# Epoch 53/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4159 - accuracy: 0.8122 - val_loss: 0.5758 - val_accuracy: 0.6992
# Epoch 54/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.8000 - val_loss: 0.5772 - val_accuracy: 0.6911
# Epoch 55/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4149 - accuracy: 0.8122 - val_loss: 0.5796 - val_accuracy: 0.6992
# Epoch 56/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.8143 - val_loss: 0.5788 - val_accuracy: 0.6992
# Epoch 57/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4142 - accuracy: 0.8061 - val_loss: 0.5777 - val_accuracy: 0.6992
# Epoch 58/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4152 - accuracy: 0.8061 - val_loss: 0.5818 - val_accuracy: 0.6992
# Epoch 59/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4132 - accuracy: 0.8061 - val_loss: 0.5794 - val_accuracy: 0.6992
# Epoch 60/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4123 - accuracy: 0.8122 - val_loss: 0.5799 - val_accuracy: 0.6992
# Epoch 61/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4122 - accuracy: 0.8143 - val_loss: 0.5818 - val_accuracy: 0.6992
# Epoch 62/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.8122 - val_loss: 0.5839 - val_accuracy: 0.6992
# Epoch 63/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.8122 - val_loss: 0.5834 - val_accuracy: 0.6992
# Epoch 64/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4111 - accuracy: 0.8163 - val_loss: 0.5832 - val_accuracy: 0.6992
# Epoch 65/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4108 - accuracy: 0.8082 - val_loss: 0.5841 - val_accuracy: 0.6992
# Epoch 66/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4103 - accuracy: 0.8122 - val_loss: 0.5836 - val_accuracy: 0.6992
# Epoch 67/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.8143 - val_loss: 0.5851 - val_accuracy: 0.6992
# Epoch 68/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4102 - accuracy: 0.8082 - val_loss: 0.5833 - val_accuracy: 0.6992
# Epoch 69/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4096 - accuracy: 0.8122 - val_loss: 0.5855 - val_accuracy: 0.6992
# Epoch 70/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4095 - accuracy: 0.8061 - val_loss: 0.5853 - val_accuracy: 0.6992
# Epoch 71/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.4089 - accuracy: 0.8102 - val_loss: 0.5853 - val_accuracy: 0.6992
# Epoch 72/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4095 - accuracy: 0.8082 - val_loss: 0.5861 - val_accuracy: 0.6992
# Epoch 73/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4082 - accuracy: 0.8163 - val_loss: 0.5876 - val_accuracy: 0.6992
# Epoch 74/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.8163 - val_loss: 0.5879 - val_accuracy: 0.6992
# Epoch 75/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.8041 - val_loss: 0.5895 - val_accuracy: 0.6911
# Epoch 76/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.8143 - val_loss: 0.5875 - val_accuracy: 0.6911
# Epoch 77/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4073 - accuracy: 0.8061 - val_loss: 0.5877 - val_accuracy: 0.6992
# Epoch 78/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4079 - accuracy: 0.8102 - val_loss: 0.5903 - val_accuracy: 0.6829
# Epoch 79/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.4073 - accuracy: 0.8143 - val_loss: 0.5897 - val_accuracy: 0.7073
# Epoch 80/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4069 - accuracy: 0.8143 - val_loss: 0.5870 - val_accuracy: 0.6911
# Epoch 81/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4073 - accuracy: 0.8061 - val_loss: 0.5886 - val_accuracy: 0.6748
# Epoch 82/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4064 - accuracy: 0.8061 - val_loss: 0.5904 - val_accuracy: 0.6829
# Epoch 83/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4060 - accuracy: 0.8102 - val_loss: 0.5890 - val_accuracy: 0.6911
# Epoch 84/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4065 - accuracy: 0.8102 - val_loss: 0.5911 - val_accuracy: 0.6829
# Epoch 85/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4057 - accuracy: 0.8061 - val_loss: 0.5910 - val_accuracy: 0.6911
# Epoch 86/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4065 - accuracy: 0.8102 - val_loss: 0.5917 - val_accuracy: 0.6911
# Epoch 87/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4051 - accuracy: 0.8082 - val_loss: 0.5887 - val_accuracy: 0.6911
# Epoch 88/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.8122 - val_loss: 0.5916 - val_accuracy: 0.6748
# Epoch 89/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8082 - val_loss: 0.5905 - val_accuracy: 0.6829
# Epoch 90/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.8061 - val_loss: 0.5900 - val_accuracy: 0.6829
# Epoch 91/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8122 - val_loss: 0.5906 - val_accuracy: 0.6911
# Epoch 92/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4044 - accuracy: 0.8082 - val_loss: 0.5916 - val_accuracy: 0.6829
# Epoch 93/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8082 - val_loss: 0.5917 - val_accuracy: 0.6829
# Epoch 94/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8102 - val_loss: 0.5912 - val_accuracy: 0.6911
# Epoch 95/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4037 - accuracy: 0.8082 - val_loss: 0.5939 - val_accuracy: 0.6748
# Epoch 96/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.8122 - val_loss: 0.5950 - val_accuracy: 0.6911
# Epoch 97/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4035 - accuracy: 0.8122 - val_loss: 0.5931 - val_accuracy: 0.6829
# Epoch 98/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4032 - accuracy: 0.8082 - val_loss: 0.5934 - val_accuracy: 0.6911
# Epoch 99/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.8102 - val_loss: 0.5954 - val_accuracy: 0.6911
# Epoch 100/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.4031 - accuracy: 0.8102 - val_loss: 0.5936 - val_accuracy: 0.6829
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4623 - accuracy: 0.7792
# Accuracy: 77.92

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Loading the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Splitting the dataset into the training set and test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# Normalizing the data using StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy'])

# Training the model
history = model.fit(X_train, y_train, epochs=100,
                    batch_size=10, validation_split=0.2)

# Evaluating the model
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 37/37 [==============================] - 2s 11ms/step - loss: 0.6941 - accuracy: 0.5302 - val_loss: 0.6296 - val_accuracy: 0.6923
# Epoch 2/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.6130 - accuracy: 0.7610 - val_loss: 0.5563 - val_accuracy: 0.8352
# Epoch 3/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.5220 - accuracy: 0.8297 - val_loss: 0.4728 - val_accuracy: 0.8901
# Epoch 4/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.4199 - accuracy: 0.8846 - val_loss: 0.3747 - val_accuracy: 0.9121
# Epoch 5/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.3303 - accuracy: 0.9066 - val_loss: 0.2964 - val_accuracy: 0.9451
# Epoch 6/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.9176 - val_loss: 0.2373 - val_accuracy: 0.9670
# Epoch 7/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.2250 - accuracy: 0.9286 - val_loss: 0.1989 - val_accuracy: 0.9670
# Epoch 8/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.1957 - accuracy: 0.9368 - val_loss: 0.1695 - val_accuracy: 0.9670
# Epoch 9/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.1739 - accuracy: 0.9423 - val_loss: 0.1471 - val_accuracy: 0.9670
# Epoch 10/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.9505 - val_loss: 0.1285 - val_accuracy: 0.9890
# Epoch 11/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.1405 - accuracy: 0.9533 - val_loss: 0.1115 - val_accuracy: 0.9890
# Epoch 12/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.1251 - accuracy: 0.9670 - val_loss: 0.0985 - val_accuracy: 0.9890
# Epoch 13/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9670 - val_loss: 0.0905 - val_accuracy: 0.9890
# Epoch 14/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.1062 - accuracy: 0.9725 - val_loss: 0.0841 - val_accuracy: 0.9890
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.1005 - accuracy: 0.9725 - val_loss: 0.0791 - val_accuracy: 0.9890
# Epoch 16/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.9725 - val_loss: 0.0757 - val_accuracy: 0.9890
# Epoch 17/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0920 - accuracy: 0.9753 - val_loss: 0.0721 - val_accuracy: 0.9890
# Epoch 18/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0886 - accuracy: 0.9753 - val_loss: 0.0698 - val_accuracy: 0.9890
# Epoch 19/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0859 - accuracy: 0.9753 - val_loss: 0.0668 - val_accuracy: 0.9890
# Epoch 20/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9753 - val_loss: 0.0653 - val_accuracy: 0.9780
# Epoch 21/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0812 - accuracy: 0.9780 - val_loss: 0.0632 - val_accuracy: 0.9780
# Epoch 22/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0790 - accuracy: 0.9808 - val_loss: 0.0617 - val_accuracy: 0.9780
# Epoch 23/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9835 - val_loss: 0.0594 - val_accuracy: 0.9780
# Epoch 24/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9835 - val_loss: 0.0581 - val_accuracy: 0.9780
# Epoch 25/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0734 - accuracy: 0.9835 - val_loss: 0.0574 - val_accuracy: 0.9780
# Epoch 26/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9835 - val_loss: 0.0566 - val_accuracy: 0.9780
# Epoch 27/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9835 - val_loss: 0.0544 - val_accuracy: 0.9780
# Epoch 28/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0692 - accuracy: 0.9835 - val_loss: 0.0538 - val_accuracy: 0.9780
# Epoch 29/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0680 - accuracy: 0.9835 - val_loss: 0.0531 - val_accuracy: 0.9780
# Epoch 30/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9835 - val_loss: 0.0511 - val_accuracy: 0.9780
# Epoch 31/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.9835 - val_loss: 0.0509 - val_accuracy: 0.9780
# Epoch 32/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9835 - val_loss: 0.0511 - val_accuracy: 0.9670
# Epoch 33/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0631 - accuracy: 0.9835 - val_loss: 0.0496 - val_accuracy: 0.9670
# Epoch 34/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0616 - accuracy: 0.9863 - val_loss: 0.0489 - val_accuracy: 0.9670
# Epoch 35/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0605 - accuracy: 0.9863 - val_loss: 0.0478 - val_accuracy: 0.9670
# Epoch 36/100
# 37/37 [==============================] - 0s 10ms/step - loss: 0.0598 - accuracy: 0.9863 - val_loss: 0.0492 - val_accuracy: 0.9670
# Epoch 37/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0581 - accuracy: 0.9863 - val_loss: 0.0484 - val_accuracy: 0.9670
# Epoch 38/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0575 - accuracy: 0.9863 - val_loss: 0.0471 - val_accuracy: 0.9670
# Epoch 39/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.9863 - val_loss: 0.0484 - val_accuracy: 0.9780
# Epoch 40/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9863 - val_loss: 0.0468 - val_accuracy: 0.9780
# Epoch 41/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9863 - val_loss: 0.0473 - val_accuracy: 0.9780
# Epoch 42/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0531 - accuracy: 0.9863 - val_loss: 0.0475 - val_accuracy: 0.9780
# Epoch 43/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9863 - val_loss: 0.0472 - val_accuracy: 0.9780
# Epoch 44/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.9863 - val_loss: 0.0462 - val_accuracy: 0.9670
# Epoch 45/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9863 - val_loss: 0.0455 - val_accuracy: 0.9780
# Epoch 46/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0497 - accuracy: 0.9863 - val_loss: 0.0453 - val_accuracy: 0.9780
# Epoch 47/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0491 - accuracy: 0.9863 - val_loss: 0.0455 - val_accuracy: 0.9780
# Epoch 48/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9863 - val_loss: 0.0452 - val_accuracy: 0.9780
# Epoch 49/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0473 - accuracy: 0.9863 - val_loss: 0.0437 - val_accuracy: 0.9780
# Epoch 50/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9863 - val_loss: 0.0427 - val_accuracy: 0.9780
# Epoch 51/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9863 - val_loss: 0.0440 - val_accuracy: 0.9780
# Epoch 52/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9863 - val_loss: 0.0441 - val_accuracy: 0.9780
# Epoch 53/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.9863 - val_loss: 0.0436 - val_accuracy: 0.9780
# Epoch 54/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0440 - accuracy: 0.9863 - val_loss: 0.0425 - val_accuracy: 0.9780
# Epoch 55/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9863 - val_loss: 0.0423 - val_accuracy: 0.9780
# Epoch 56/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9863 - val_loss: 0.0428 - val_accuracy: 0.9780
# Epoch 57/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 0.9863 - val_loss: 0.0426 - val_accuracy: 0.9780
# Epoch 58/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9863 - val_loss: 0.0421 - val_accuracy: 0.9780
# Epoch 59/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9863 - val_loss: 0.0422 - val_accuracy: 0.9780
# Epoch 60/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0409 - accuracy: 0.9863 - val_loss: 0.0420 - val_accuracy: 0.9780
# Epoch 61/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 0.9863 - val_loss: 0.0418 - val_accuracy: 0.9780
# Epoch 62/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9863 - val_loss: 0.0413 - val_accuracy: 0.9780
# Epoch 63/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0389 - accuracy: 0.9863 - val_loss: 0.0409 - val_accuracy: 0.9780
# Epoch 64/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9863 - val_loss: 0.0411 - val_accuracy: 0.9780
# Epoch 65/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0378 - accuracy: 0.9863 - val_loss: 0.0411 - val_accuracy: 0.9780
# Epoch 66/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0382 - accuracy: 0.9863 - val_loss: 0.0397 - val_accuracy: 0.9780
# Epoch 67/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 0.9863 - val_loss: 0.0391 - val_accuracy: 0.9780
# Epoch 68/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9890 - val_loss: 0.0389 - val_accuracy: 0.9780
# Epoch 69/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0359 - accuracy: 0.9863 - val_loss: 0.0386 - val_accuracy: 0.9780
# Epoch 70/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0374 - val_accuracy: 0.9780
# Epoch 71/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0344 - accuracy: 0.9890 - val_loss: 0.0371 - val_accuracy: 0.9780
# Epoch 72/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 0.9890 - val_loss: 0.0365 - val_accuracy: 0.9780
# Epoch 73/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.0368 - val_accuracy: 0.9780
# Epoch 74/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 0.0360 - val_accuracy: 0.9780
# Epoch 75/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.0355 - val_accuracy: 0.9780
# Epoch 76/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 0.9890 - val_loss: 0.0360 - val_accuracy: 0.9780
# Epoch 77/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9890 - val_loss: 0.0356 - val_accuracy: 0.9780
# Epoch 78/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.0348 - val_accuracy: 0.9780
# Epoch 79/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9890 - val_loss: 0.0339 - val_accuracy: 0.9780
# Epoch 80/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9890 - val_loss: 0.0340 - val_accuracy: 0.9780
# Epoch 81/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9890 - val_loss: 0.0329 - val_accuracy: 0.9780
# Epoch 82/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9890 - val_loss: 0.0336 - val_accuracy: 0.9780
# Epoch 83/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9890 - val_loss: 0.0336 - val_accuracy: 0.9780
# Epoch 84/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9890 - val_loss: 0.0340 - val_accuracy: 0.9780
# Epoch 85/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 0.9890 - val_loss: 0.0345 - val_accuracy: 0.9780
# Epoch 86/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9890 - val_loss: 0.0340 - val_accuracy: 0.9780
# Epoch 87/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9890 - val_loss: 0.0337 - val_accuracy: 0.9780
# Epoch 88/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0263 - accuracy: 0.9890 - val_loss: 0.0339 - val_accuracy: 0.9780
# Epoch 89/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9918 - val_loss: 0.0329 - val_accuracy: 0.9780
# Epoch 90/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9890 - val_loss: 0.0317 - val_accuracy: 0.9780
# Epoch 91/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 0.9918 - val_loss: 0.0319 - val_accuracy: 0.9780
# Epoch 92/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9918 - val_loss: 0.0324 - val_accuracy: 0.9780
# Epoch 93/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.0315 - val_accuracy: 0.9780
# Epoch 94/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.0313 - val_accuracy: 0.9780
# Epoch 95/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0235 - accuracy: 0.9918 - val_loss: 0.0309 - val_accuracy: 0.9780
# Epoch 96/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9918 - val_loss: 0.0300 - val_accuracy: 0.9780
# Epoch 97/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9918 - val_loss: 0.0296 - val_accuracy: 0.9780
# Epoch 98/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9918 - val_loss: 0.0296 - val_accuracy: 0.9780
# Epoch 99/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9918 - val_loss: 0.0295 - val_accuracy: 0.9780
# Epoch 100/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 0.0301 - val_accuracy: 0.9780
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2025 - accuracy: 0.9386
# Accuracy: 93.86

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Flatten the images
image_size = x_train.shape[1] * x_train.shape[2]
x_train = x_train.reshape((x_train.shape[0], image_size))
x_test = x_test.reshape((x_test.shape[0], image_size))

# Scale the pixel values from range [0, 255] to [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert class labels to one-hot encoded vectors
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# Define the model
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=image_size))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model and save the history object
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

# Plot the loss and accuracy for both training and validation data
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 469/469 [==============================] - 4s 7ms/step - loss: 0.3280 - accuracy: 0.9068 - val_loss: 0.1559 - val_accuracy: 0.9522
# Epoch 2/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1336 - accuracy: 0.9612 - val_loss: 0.1069 - val_accuracy: 0.9679
# Epoch 3/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0931 - accuracy: 0.9719 - val_loss: 0.0967 - val_accuracy: 0.9695
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0709 - accuracy: 0.9784 - val_loss: 0.0795 - val_accuracy: 0.9759
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0551 - accuracy: 0.9833 - val_loss: 0.0794 - val_accuracy: 0.9753
# Epoch 6/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0436 - accuracy: 0.9865 - val_loss: 0.0865 - val_accuracy: 0.9729
# Epoch 7/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0360 - accuracy: 0.9891 - val_loss: 0.0740 - val_accuracy: 0.9778
# Epoch 8/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0282 - accuracy: 0.9914 - val_loss: 0.0735 - val_accuracy: 0.9777
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.0846 - val_accuracy: 0.9776
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.0856 - val_accuracy: 0.9767
# Epoch 11/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0899 - val_accuracy: 0.9762
# Epoch 12/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.0883 - val_accuracy: 0.9757
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0916 - val_accuracy: 0.9769
# Epoch 14/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.0929 - val_accuracy: 0.9757
# Epoch 15/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.1126 - val_accuracy: 0.9732
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0911 - val_accuracy: 0.9792
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.1005 - val_accuracy: 0.9769
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.1000 - val_accuracy: 0.9761
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.1043 - val_accuracy: 0.9787
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0953 - val_accuracy: 0.9787

# %%
import keras

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# reshape the data to a 1D array of pixels
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# convert data type to float32 and normalize the data to a range between 0 and 1
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# convert labels to categorical one-hot encoding
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# define the model architecture
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# print the model summary
model.summary()

# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

# train the model
history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=20,
                    verbose=1,
                    validation_data=(x_test, y_test))

# plot the training and validation loss and accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# select a random image from the test data
idx = np.random.randint(x_test.shape[0])
image = x_test[idx].reshape(28, 28)

# plot the selected image
plt.figure()
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title('Selected Image')

# do inferencing to check the model prediction on the selected image
prediction = model.predict(image.reshape(1, 784))
prediction = np.argmax(prediction)

# print the predicted label
print('Predicted label:', prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 23
#      21 # convert labels to categorical one-hot encoding
#      22 num_classes = 10
# ---> 23 y_train = keras.utils.to_categorical(y_train, num_classes)
#      24 y_test = keras.utils.to_categorical(y_test, num_classes)
#      26 # define the model architecture
#
# NameError: name 'keras' is not defined

# %%
# Load the MNIST dataset
import matplotlib.pyplot as plt
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Convert the pixel values to floats and normalize them to the range 0-1
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert the target variable to a one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create a neural network model with 3 hidden layers and tanh activation

model = Sequential()
model.add(Dense(256, input_dim=784, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(x_train.reshape(-1, 784), y_train, epochs=10,
                    validation_data=(x_test.reshape(-1, 784), y_test))

# Plot the loss and accuracy for both training and validation data

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 7ms/step - loss: 0.2353 - accuracy: 0.9297 - val_loss: 0.1444 - val_accuracy: 0.9569
# Epoch 2/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1113 - accuracy: 0.9660 - val_loss: 0.1006 - val_accuracy: 0.9704
# Epoch 3/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0784 - accuracy: 0.9761 - val_loss: 0.1034 - val_accuracy: 0.9685
# Epoch 4/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0595 - accuracy: 0.9816 - val_loss: 0.0955 - val_accuracy: 0.9707
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0467 - accuracy: 0.9850 - val_loss: 0.0774 - val_accuracy: 0.9761
# Epoch 6/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0745 - val_accuracy: 0.9769
# Epoch 7/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0339 - accuracy: 0.9890 - val_loss: 0.0798 - val_accuracy: 0.9754
# Epoch 8/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0299 - accuracy: 0.9903 - val_loss: 0.0818 - val_accuracy: 0.9763
# Epoch 9/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0255 - accuracy: 0.9919 - val_loss: 0.0840 - val_accuracy: 0.9771
# Epoch 10/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0900 - val_accuracy: 0.9747

# %%
# Load the MNIST dataset
import matplotlib.pyplot as plt
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Flatten the input images
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# Convert the target variable to a one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create a neural network model with 2 hidden layers and Relu activation

model = Sequential()
model.add(Dense(256, input_dim=784, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10,
                    validation_data=(x_test, y_test))

# Plot the loss and accuracy for both training and validation data

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.5906 - accuracy: 0.8899 - val_loss: 0.3367 - val_accuracy: 0.9277
# Epoch 2/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.2305 - accuracy: 0.9396 - val_loss: 0.2526 - val_accuracy: 0.9412
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1765 - accuracy: 0.9522 - val_loss: 0.1698 - val_accuracy: 0.9563
# Epoch 4/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1506 - accuracy: 0.9590 - val_loss: 0.1942 - val_accuracy: 0.9515
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1300 - accuracy: 0.9646 - val_loss: 0.1515 - val_accuracy: 0.9633
# Epoch 6/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1168 - accuracy: 0.9676 - val_loss: 0.1641 - val_accuracy: 0.9634
# Epoch 7/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1051 - accuracy: 0.9717 - val_loss: 0.1377 - val_accuracy: 0.9639
# Epoch 8/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0968 - accuracy: 0.9746 - val_loss: 0.1458 - val_accuracy: 0.9656
# Epoch 9/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0877 - accuracy: 0.9769 - val_loss: 0.1695 - val_accuracy: 0.9648
# Epoch 10/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0819 - accuracy: 0.9792 - val_loss: 0.1567 - val_accuracy: 0.9668
